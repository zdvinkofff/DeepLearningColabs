# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/vor.csv', skiprows=0, sep=';', encoding='1251')
df
# Out:
#                                                                                                                                            Воронеж (город)
# Время Дата     Напр.ветра Ск.ветра Видим. Явл. Обл.        Форма обл. Т     Тd   f  Тe  Pmin   dP   Po     Тmin  Tmax  R   s   Сост.почвы              NaN
# 00    08.05.22 160        1        10 км  NaN  4/0 верхняя [Ci fib]   +5.1  -1.8 61 +6  1027   -0.3 1008.5 NaN   NaN   NaN NaN NaN                     NaN
# 03    08.05.22 тихо       NaN      10 км  NaN  8/0 верхняя [Ci fib]   +5    +0.7 74 +5  1026.7 -0.3 1008.2 +4.2  NaN   NaN NaN сухая                   NaN
# 06    08.05.22 160        2        10 км  NaN  8/0 верхняя [Ci fib]   +14.7 -2.2 31 +15 1026   0    1008.2 NaN   NaN   NaN NaN NaN                     NaN
# 09    08.05.22 160        4        10 км  NaN  6/0 верхняя [Ci fib]   +18.1 -3.5 23 +18 1024.3 -1.5 1006.7 NaN   NaN   NaN NaN NaN                     NaN
# ...
